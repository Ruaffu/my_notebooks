# %% [markdown]
# 1.A

# %%
import ex2_functions
file = "../data/rodents.csv"
ex2_functions.print_file_content(file)
# Out:
# ['weight;height;type\n', '233.4799204165095;23.514129929623852;rat\n', '231.32446731816555;26.03382997978225;rat\n', '17.906954059999567;6.846576762459397;mouse\n', '230.276522831171;24.077799766119398;rat\n', '20.36059265800554;6.6059829255227;mouse\n', '21.60538751773697;6.812460032530713;mouse\n', '17.857287204810735;11.035404495152587;rat\n', '22.126466425940755;3.4264119947433698;mouse\n', '16.705945556222066;10.224681485508848;rat\n', ';24.860580892741382;rat\n', '17.829895696869293;1.760933366281141;mouse\n', '229.8825053203199;24.294666648974516;rat\n', '17.73055576623651;9.557056204224441;mouse\n', '20.482512894265184;8.380479488301278;mouse\n', '226.24154553825502;20.875410886871094;rat\n', '18.080583092046673;9.2341758846312;mouse\n', '228.29767458614975;25.279481079749164;rat\n', '18.139424493959215;2.504234964041916;mouse\n', '232.0666423133437;27.21859650129202;rat\n', '20.63372735668096;6.48930255532786;mouse\n', '23.59044761203051;5.498694396861257;mouse\n', '227.5196
# ...

# %% [markdown]
# 1.B

# %%
import ex2_functions
file = "test files/test.txt"
tuples = [("bo","sam",("ro","mo"))]
ex2_functions.write_list_to_file(file, tuples)
ex2_functions.print_file_content(file)
# Out:
# ["('bo', 'sam', ('ro', 'mo'))\n"]

# %%
1.B.a

# %%
import ex2_functions
file = "test files/test.txt"
tuples = [("bo","sam",("ro","mo"))]
ex2_functions.write_list_to_file2(file, "hello", "world","I","have","been","added","to","file")
ex2_functions.print_file_content(file)
# Out:
# ['hello\n', 'world\n', 'I\n', 'have\n', 'been\n', 'added\n', 'to\n', 'file\n']

# %% [markdown]
# 1.C

# %%
import ex2_functions
file = "../data/rodents.csv"
list = ex2_functions.read_csv(file)
print(list)
# Out:
# ['weight;height;type\n', '233.4799204165095;23.514129929623852;rat\n', '231.32446731816555;26.03382997978225;rat\n', '17.906954059999567;6.846576762459397;mouse\n', '230.276522831171;24.077799766119398;rat\n', '20.36059265800554;6.6059829255227;mouse\n', '21.60538751773697;6.812460032530713;mouse\n', '17.857287204810735;11.035404495152587;rat\n', '22.126466425940755;3.4264119947433698;mouse\n', '16.705945556222066;10.224681485508848;rat\n', ';24.860580892741382;rat\n', '17.829895696869293;1.760933366281141;mouse\n', '229.8825053203199;24.294666648974516;rat\n', '17.73055576623651;9.557056204224441;mouse\n', '20.482512894265184;8.380479488301278;mouse\n', '226.24154553825502;20.875410886871094;rat\n', '18.080583092046673;9.2341758846312;mouse\n', '228.29767458614975;25.279481079749164;rat\n', '18.139424493959215;2.504234964041916;mouse\n', '232.0666423133437;27.21859650129202;rat\n', '20.63372735668096;6.48930255532786;mouse\n', '23.59044761203051;5.498694396861257;mouse\n', '227.5196
# ...

# %% [markdown]
# 2.A

# %% [markdown]
# 2.B

# %% [markdown]
# 3.

# %% [markdown]
# 2.

# %%
import utils
path = "../data"
utils.get_file_names(path)

# %%
import utils
path = "../modules"
utils.get_all_file_names(path)

# %%
import utils
files = ["mo.txt", "bo.txt"]
utils.print_line_one(files)
# Out:
# bob
#
# ya

# %%
import utils
file = ["mo.txt"]
utils.print_emails(file)
# Out:
# snape@hogwarts.magic
#
# potter@hogwarts.magic

# %%
import utils
file = ["README.md"]
utils.write_headlines(file)
